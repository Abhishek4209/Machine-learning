# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Q1:-**
# ### **Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?**

# %% [markdown]
# ### **Ans:-**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("flight_price.xlsx - Sheet1.csv")
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
print("There are {} Rows for {} columns.".format(df.shape[0],df.shape[1]))
# Out:
# There are 10683 Rows for 11 columns.

# %% [markdown]
# ## **Q2:-**
# ### **What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.**

# %% [markdown]
# ### **Ans:-**

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Price"],kde=True)
plt.show()

# %%
plt.figure(figsize=(12, 12))
for column in df.columns:
    plt.subplot(3, 4, list(df.columns).index(column) + 1)
    sns.histplot(df[column], kde=True)
    plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Q3:-**
# ### **What is the range of prices in the dataset? What is the minimum and maximum price?**

# %% [markdown]
# ### **Ans:-**

# %%
print("Minimum value:",df["Price"].describe()[3])
print("Maximum value:",df["Price"].describe()[7])
# Out:
# Minimum value: 1759.0
# Maximum value: 79512.0

# %% [markdown]
# ## **Q4:-**
# ### **How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.**

# %% [markdown]
# ### **Ans:-**

# %%
airlines=df[["Airline"]]
airlines_list=list(airlines.unique())
airlines_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2848\3300669322.py in ?()
#       1 airlines=df[["Airline"]]
# ----> 2 airlines_list=list(airlines.unique())
#       3 airlines_list
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
prices=df["Price"]
prices_list=list((prices))

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual dataset)
airlines = airlines_list
prices = prices_list# Prices for Airline D

# Create a boxplot
plt.figure(figsize=(10, 6))
plt.boxplot(prices,labels=airlines_list )
plt.title('Flight Prices by Airline')
plt.xlabel('Airline')
plt.ylabel('Price (in USD)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\PW-DATA SCIENCE\Week-14\Assignment_Exploratory Data  Analysis-2.ipynb Cell 19 line 9
#       <a href='vscode-notebook-cell:/d%3A/PW-DATA%20SCIENCE/Week-14/Assignment_Exploratory%20Data%20%20Analysis-2.ipynb#Y125sZmlsZQ%3D%3D?line=6'>7</a> # Create a boxplot
#       <a href='vscode-notebook-cell:/d%3A/PW-DATA%20SCIENCE/Week-14/Assignment_Exploratory%20Data%20%20Analysis-2.ipynb#Y125sZmlsZQ%3D%3D?line=7'>8</a> plt.figure(figsize=(10, 6))
# ----> <a href='vscode-notebook-cell:/d%3A/PW-DATA%20SCIENCE/Week-14/Assignment_Exploratory%20Data%20%20Analysis-2.ipynb#Y125sZmlsZQ%3D%3D?line=8'>9</a> plt.boxplot(prices,labels=airlines_list )
#      <a href='vscode-notebook-cell:/d%3A/PW-DATA%20SCIENCE/Week-14/Assignment_Exploratory%20Data%20%20Analysis-2.ipynb#Y125sZmlsZQ%3D%3D?line=9'>10</a> plt.title('Flight Prices by Airline')
#      <a href='vscode-notebook-cell:/d%3A/PW-DATA%20SCIENCE/Week-14/Assignment_Exploratory%20Data%20%20Analysis-2.ipynb#Y125sZmlsZQ%3D%3D?line=10'>11</a> plt.xlabel('Airline')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:2483, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2473 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2474 def boxplot(
#    2475         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2481         whiskerprops=None, manage_ticks=True, autorange=False,
#    2482         zorder=None, capwidths=None, *, data=None):
# -> 2483     return gca().boxplot(
#    2484         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2485         positions=positions, widths=widths, patch_artist=patch_artist,
#    2486         bootstrap=bootstrap, usermedians=usermedians,
#    2487         conf_intervals=conf_intervals, meanline=meanline,
#    2488         showmeans=showmeans, showcaps=showcaps, showbox=showbox,
#    2489         showfliers=showfliers, boxprops=boxprops, labels=labels,
#    2490         flierprops=flierprops, medianprops=medianprops,
#    2491         meanprops=meanprops, capprops=capprops,
#    2492         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2493         autorange=autorange, zorder=zorder, capwidths=capwidths,
#    2494         **({"data": data} if data is not None else {}))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_axes.py:3914, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths)
#    3911 if bootstrap is None:
#    3912     bootstrap = mpl.rcParams['boxplot.bootstrap']
# -> 3914 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3915                                labels=labels, autorange=autorange)
#    3916 if notch is None:
#    3917     notch = mpl.rcParams['boxplot.notch']
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\cbook\__init__.py:1198, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1196     labels = itertools.repeat(None)
#    1197 elif len(labels) != ncols:
# -> 1198     raise ValueError("Dimensions of labels and X must be compatible")
#    1200 input_whis = whis
#    1201 for ii, (x, label) in enumerate(zip(X, labels)):
#    1202
#    1203     # empty dict
#
# ValueError: Dimensions of labels and X must be compatible

# %% [markdown]
# ## **Q5:-**
# ### **Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.**

# %% [markdown]
# ### **Ans:-**

# %%
sns.boxplot(df)

# %% [markdown]
# ## **Q6:-**
# ### **You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?**

# %% [markdown]
# ### **Ans:-**

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\PW-DATA SCIENCE\Week-14\Assignment_Exploratory Data  Analysis-2.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PW-DATA%20SCIENCE/Week-14/Assignment_Exploratory%20Data%20%20Analysis-2.ipynb#Y133sZmlsZQ%3D%3D?line=0'>1</a> df.corr()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'IndiGo'

# %% [markdown]
# ## **Q7:-**
# ### **You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?**

# %% [markdown]
# ### **Ans:-**

# %% [markdown]
# ## **Q8:-**
# ### **You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?**

# %% [markdown]
# ### **Ans:-**

# %% [markdown]
# # **Google Playstore:**

# %% [markdown]
# ## **Q9:-**
# ### **Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?**

# %% [markdown]
# ### **Ans:-**

# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("googleplaystore.csv")
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
print("There are {} Rows for {} columns.".format(df.shape[0],df.shape[1]))
# Out:
# There are 10841 Rows for 13 columns.

# %% [markdown]
# ## **Q10:-**
# ### **How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.**

# %% [markdown]
# ### **Ans:-**

# %%
cat=list(df["Category"].unique())
cat=list(df["Category"].unique())

# %%
import numpy as np  
import matplotlib.pyplot as plt  

X = cat
Ygirls =  
Zboys = [20,30,25,30] 


plt.bar(X_axis - 0.2, Ygirls, 0.4, label = 'Girls') 
plt.bar(X_axis + 0.2, Zboys, 0.4, label = 'Boys') 
  
plt.xticks(X_axis, X) 
plt.xlabel("Groups") 
plt.ylabel("Number of Students") 
plt.title("Number of Students in each group") 
plt.legend() 
plt.show()
# Out:
#   Cell In[14], line 5
#     Ygirls =
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset into a DataFrame
# df = pd.read_csv("your_dataset.csv")

# Create a boxplot
# plt.figure(figsize=(10, 6))
plt.xticks(rotation=90)
plt.title("App Ratings by Category")
plt.xlabel("Category")
plt.ylabel("Rating")
plt.boxplot([df[df['Category'] == category]['Rating'] for category in df['Category'].unique()], labels=df['Category'].unique())
plt.show()

# %%
sns.distplot(x=df["Rating"],kde=True)

# %%
plt.figure(figsize=(10,15))
sns.boxplot(x=df["Rating"],y=df["Category"])
plt.show()

# %% [markdown]
# ## **Q11:-**
# ### **Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.**

# %% [markdown]
# ### **Ans:-**

# %%
df.isnull().sum()

# %% [markdown]
# #### Here we can see that 'Rating' is a parameter which have 1474 missing values.
# #### Here we can see that 'Type' is a parameter which have 1 missing values.
# #### Here we can see that 'Content Rating' is a parameter which have 1 missing values.
# #### Here we can see that 'Current Ver' is a parameter which have 8 missing values.
# #### Here we can see that 'Android Ver' is a parameter which have 3 missing values.

# %% [markdown]
# ## They are impact on our model to predection , then we can handle missing value and replace by its central values.

# %% [markdown]
# ## **Q12:-**
# ### **What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.**

# %% [markdown]
# ### **Ans:-**

# %%
x=df["Rating"]
y=df["Size"]
plt.scatter(x,y)

# %% [markdown]
# ## **Q13:-**
# ### **How does the type of app affect its price? Create a bar chart to compare average prices by app type.**

# %% [markdown]
# ### **Ans:-**

# %%
plt

# %% [markdown]
# ## **Q14:-**
# ### **What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.**

# %% [markdown]
# ### **Ans:-**

# %% [markdown]
# ## **Q15:-**
# ### **A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?**

# %% [markdown]
# ### **Ans:-**

# %% [markdown]
# ## **Q16:-**
# ### **A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?**

# %% [markdown]
# ### **Ans:-**

# %% [markdown]
# ## **Q17:-**
# ### **A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?**

# %% [markdown]
# ### **Ans:-**

# %% [markdown]
# #### **Note:- You can use Flight Price and Google Playstore Dataset as per the discussion in lecture.**
